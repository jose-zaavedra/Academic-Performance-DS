# %% [markdown]
# # Exploracion inicial del rendimiento academico
#
# Este notebook es el punto de partida para cargar y revisar los datos del proyecto.

# %%
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path.cwd().parent
RAW_DATA_DIR = PROJECT_ROOT / 'data' / 'raw'
PROCESSED_DATA_DIR = PROJECT_ROOT / 'data' / 'processed'
OUTPUT_DIR = PROJECT_ROOT / 'output'

print(f'Datos originales: {RAW_DATA_DIR}')
print(f'Datos procesados: {PROCESSED_DATA_DIR}')
print(f'Resultados: {OUTPUT_DIR}')

# %% [markdown]
# ## Proximos pasos
#
# 1. Colocar el dataset original en `data/raw/`.
# 2. Cargarlo con pandas y revisar tipos, faltantes y duplicados.
# 3. Guardar las transformaciones en `data/processed/`.
# 4. Exportar visualizaciones y tablas a `output/`.
